# %% [markdown]
# # Definitions:
#
# 1. What is tourism ? :
# * Tourism, in a statistical context, refers to the activity of visitors taking a trip to a destination outside their usual environment, for less than a year. It can be for any main purpose, including business or leisure.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Questions:

# %% [markdown]
# ## 1. How factors such as sex, age, education, income and employment affect the participation of people in tourism ?
# here we will be considering sex

# %% [markdown]
# ## Cleaning

# %% [markdown]
# Meta Data :
# https://ec.europa.eu/eurostat/web/tourism/methodology

# %%
# read  and clean

orig_sex = pd.read_csv('data/tour_dem_tosex.tsv', sep='\t')

def clean(data):
    # remove white spaces
    data.columns = data.columns.str.strip() # remove space from column name
    data = data.applymap(lambda x: x.strip() if isinstance(x, str) else x)

    # remove flags from numeric columns
    data.iloc[:,1:] = data.iloc[:,1:].applymap(lambda x: x.strip('bepucfrzdns').strip() if isinstance(x, str) else x)

    # replace ':' with NAN
    data.replace(':', np.NaN, inplace=True)

    # cast columns to number (it will be float since we also have percentages)
    data.iloc[:,1:] = data.iloc[:,1:].applymap(lambda x: pd.to_numeric(x))
    
    return data

orig_sex = clean(orig_sex)

# %%
# turn the first column into different columns 'specs'
specs = orig_sex.iloc[:,0].str.split(',', expand=True)
specs.columns = ['unit', 'duration', 'partner', 'sex', 'geo_time']
# now join with the numeric data
sex_number = pd.concat([specs, orig_sex.iloc[:,1:]], axis=1)
sex_number.sample()
# Out:
#     unit duration partner sex geo_time   2018   2017   2016   2015   2014  \
# 307   NR    N_GE1     DOT   T       LU  13413  42628  40299  55555  43188
#
#      ... 2003 2002 2001 2000 1999 1998 1997 1996 1995 1994
# 307  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [1 rows x 30 columns]

# %%
# turn country codes into names
country_info = pd.read_excel('data/country_info.xls')
country_info = country_info.set_index('CODE')
country_info = country_info.iloc[:,0:1]

# turn the dataframe into dictionary
di = country_info.to_dict()['LIBEN']

# keep the country codes
#sex_number['country_code'] = sex_number['geo_time']
# turn code into name
sex_number['geo_time'] = sex_number['geo_time'].map(di).fillna(sex_number['geo_time'])

# %% [markdown]
# for now we will concentrate on the most general data possible:
#
# * unit: NR (number of people)
# * duration: N_GE1 (1 nights or more)
# * partner: OUT (outbound trips; trips of non-citizens to this country)
# * sex and geo all of the options

# %%
selection = (sex_number.unit=='NR') & (sex_number.duration=='N_GE1') & (sex_number.partner=='OUT')
sex_number = sex_number[selection]

# drop spec columns
sex_number.drop(labels=['unit', 'duration', 'partner'], axis =1, inplace=True)

# %%
sex_number.sample()
# Out:
#     sex     geo_time         2018        2017         2016         2015  \
# 360   M  Switzerland  1.19737e+06  1.1947e+06  1.24940e+06  1.16443e+06
#
#             2014         2013         2012 2011  ... 2003 2002 2001 2000 1999  \
# 360  1.07759e+06  1.01319e+06  1.06231e+06  NaN  ...  NaN  NaN  NaN  NaN  NaN
#
#     1998 1997 1996 1995 1994
# 360  NaN  NaN  NaN  NaN  NaN
#
# [1 rows x 27 columns]

# %% [markdown]
# remove the flags from numbers

# %% [markdown]
# below we can see that years 2011 and before have no data available.
# so just drop them.

# %%
sex_number.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108 entries, 321 to 428
# Data columns (total 27 columns):
# sex         108 non-null object
# geo_time    108 non-null object
# 2018        96 non-null object
# 2017        87 non-null object
# 2016        90 non-null object
# 2015        90 non-null object
# 2014        90 non-null object
# 2013        87 non-null object
# 2012        84 non-null object
# 2011        0 non-null object
# 2010        0 non-null object
# 2009        0 non-null object
# 2008        0 non-null object
# 2007        0 non-null object
# 2006        0 non-null object
# 2005        0 non-null object
# 2004        0 non-null object
# 2003        0 non-null object
# 2002        0 non-null object
# 2001        0 non-null object
# 2000        0 non-null object
# 1999        0 non-null object
# 1998        0 non-null object
# 1997        0 non-null object
# 1996        0 non-null object
# 1995        0 non-null object
# 1994        0 non-null object
# dtypes: object(27)
# memory usage: 23.6+ KB

# %%
sex_number = sex_number[['sex', 'geo_time', '2018', '2017', '2016', '2015', '2014', '2013', '2012']]

# %%
sex_number.head()
# Out:
#     sex     geo_time         2018         2017         2016         2015  \
# 321   F      Austria          NaN       838835       918136       851988
# 322   F      Belgium  1.38208e+06  1.38168e+06   2.0375e+06  1.80593e+06
# 323   F     Bulgaria        79698        71317        60132        80382
# 324   F  Switzerland   1.3868e+06  1.38865e+06  1.33264e+06  1.18564e+06
# 325   F       Cyprus        71825        73809        71415        63822
#
#             2014         2013         2012
# 321       932835       772313       728926
# 322   1.8944e+06  1.93193e+06  1.48748e+06
# 323        46790        64067        58430
# 324  1.17348e+06  1.08165e+06       999580
# 325        67892        69677       120015

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Female:

# %%
female = sex_number[sex_number.sex == 'F']
female.set_index('geo_time', inplace=True)
# sort columns
female = female.reindex(sorted(female.columns), axis=1)
# take the rows EU25/27/28 and EA out also column sex
female = female.drop(['EU25', 'EU27', 'EU28', 'EA'], axis=0).drop('sex',axis=1)

female.head()
# Out:
#                     2012         2013         2014         2015         2016  \
# geo_time
# Austria           728926       772313       932835       851988       918136
# Belgium      1.48748e+06  1.93193e+06   1.8944e+06  1.80593e+06   2.0375e+06
# Bulgaria           58430        64067        46790        80382        60132
# Switzerland       999580  1.08165e+06  1.17348e+06  1.18564e+06  1.33264e+06
# Cyprus            120015        69677        67892        63822        71415
#
#                     2017         2018
# geo_time
# Austria           838835          NaN
# Belgium      1.38168e+06  1.38208e+06
# Bulgaria           71317        79698
# Switzerland  1.38865e+06   1.3868e+06
# Cyprus             73809        71825

# %%
# normalize by dividing by year total
female_normalized = female / female.sum(axis=0)

# %% [markdown]
# We will plot the total percentages/number of female tourists to these countries in 6 plot :
# 1. with less than total 0.05 percent of travelers
# 2. between 0.05% and 0.3%
# 3. more than 0.3%

# %%
female_normalized[female_normalized.sum(axis=1) < 0.05].T.plot(figsize=(10,8))
plt.title('less than total 0.05');

# %%
female[female.sum(axis=1) < 10**6].T.plot(figsize=(10,8))
plt.title('less than 1 million');

# %%
female_normalized[(female_normalized.sum(axis=1) >= 0.05) & (female_normalized.sum(axis=1) <=  0.3 )].T.plot(figsize=(10,8))
plt.title('between 0.05% and 0.3%');

# %%
female[(female.sum(axis=1) >= 10**6) & (female.sum(axis=1) <=  5*10**6 )].T.plot(figsize=(10,8))
plt.title('between 1 and 5 million');

# %%
female_normalized[ (female_normalized.sum(axis=1) >  0.3 )].T.plot(figsize=(10,8))
plt.title('more than 0.3%');

# %%
female[ (female.sum(axis=1) >  5*10**6 )].T.plot(figsize=(10,8))
plt.title('more than 5 million');

# %% [markdown]
# **Conclusion**:
# we can clearly see that UK and and Germany have more female travelers and this is becasuse the total number of travellers to thses countries are much higer than the rest.

# %% [markdown]
# #### in sum of all years available which coutries had the most female tourists ?

# %% [markdown]
# below we see the top ten famous destinations for females.

# %%
female_top = female.sum(axis=1).sort_values(ascending=False).head(10)
female_top
# Out:
# geo_time
# Germany           38775572.0
# United Kingdom    28361310.0
# Italy             13636545.0
# Belgium           11921004.0
# Netherlands       10429054.0
# Poland             8974474.0
# Switzerland        8548444.0
# France             7300900.0
# Spain              6652214.0
# Denmark            6450076.0
# dtype: float64

# %% [markdown]
# and least famous :

# %%
female.sum(axis=1).sort_values(ascending=True).head(10)
# Out:
# geo_time
# Montenegro                                          0.0
# Former Yugoslav Republic of Macedonia, the     164642.0
# Malta                                          293612.0
# Bulgaria                                       460816.0
# Cyprus                                         538455.0
# Latvia                                         555748.0
# Estonia                                        587151.0
# Romania                                        824906.0
# Finland                                        847514.0
# Greece                                        1115367.0
# dtype: float64

# %% [markdown]
# ### Male:

# %%
male = sex_number[sex_number.sex == 'M']
male.set_index('geo_time', inplace=True)
# sort columns
male = male.reindex(sorted(male.columns), axis=1)
# take the rows EU25/27/28 and EA out also column sex
male = male.drop(['EU25', 'EU27', 'EU28', 'EA'], axis=0).drop('sex',axis=1)

# %%
male.head()
# Out:
#                     2012         2013         2014         2015         2016  \
# geo_time
# Austria           795708       764995       808542       859790       823124
# Belgium      1.50871e+06  1.80892e+06  1.77008e+06  1.62195e+06  1.72684e+06
# Bulgaria           52560        57767        38456        59004        56773
# Switzerland  1.06231e+06  1.01319e+06  1.07759e+06  1.16443e+06  1.24940e+06
# Cyprus            108453        63370        54986        52913        61884
#
#                     2017         2018
# geo_time
# Austria           839802          NaN
# Belgium      1.38139e+06   1.3391e+06
# Bulgaria           70245        63791
# Switzerland   1.1947e+06  1.19737e+06
# Cyprus             68387        66496

# %%
male.T.plot(figsize=(15,10))

# %%
male_top = male.sum(axis=1).sort_values(ascending=False).head(10)

# %%
male_top
# Out:
# geo_time
# Germany           38775370.0
# United Kingdom    28484290.0
# Italy             12851704.0
# Netherlands       11338411.0
# Belgium           11157004.0
# Poland             9237432.0
# Switzerland        7958994.0
# France             7133047.0
# Denmark            6355588.0
# Spain              6176172.0
# dtype: float64

# %% [markdown]
# Lets look at the ratios of female to male. and plot them in the Europe map.

# %%
female_male_ratios = female/ male
# unpivot the data
data = female_male_ratios.reset_index()
data = pd.melt(data, id_vars=['geo_time'], value_vars=['2018', '2017', '2016', '2015', '2014', '2013', '2012'])
#data

# %%
import json
import geopandas as gpd
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar
from bokeh.palettes import brewer

def clean_to_plot(data, unpivot=True):
    # get country out of index
    data = data.reset_index()
    # correct some country names
    data = data.replace({'Former Yugoslav Republic of Macedonia, the': 'Macedonia', 'Czech Republic': 'Czechia'})
    
    # if the data needs unpivoting do it
    if unpivot:
        # unpivot the data
        data = pd.melt(data, id_vars=['geo_time'], value_vars=['2018', '2017', '2016', '2015', '2014', '2013', '2012'])
        data = data.rename({'variable': 'year'}, axis=1)

    # read the geo data 
    shapefile = 'data/ne_50m_admin_0_countries/ne_50m_admin_0_countries.shp'#Read shapefile using Geopandas
    gdf = gpd.read_file(shapefile)[['ADMIN', 'ADM0_A3', 'geometry']]#Rename columns.
    gdf.columns = ['country', 'country_code', 'geometry']

    
    #lower case the country names for join
    gdf['country'] = gdf.country.str.lower()
    data['geo_time'] = data.geo_time.str.lower()
    # join the geo data and values
    country_values = gdf.join(data.set_index('geo_time'),on='country', how='right')
    

    
    # drop countries without coordinates
    country_values.dropna(subset=['geometry'], inplace = True)
    
    #Replace NaN values to string 'No data'.
    country_values.replace(np.nan, 'No data', inplace = True)
    
    return country_values

# %%
def plot_world_map(data, unpivot=True, Title='Title', year='2018'):
    # clean and prepare first
    country_values = clean_to_plot(data, unpivot)
    # select a year
    country_values = country_values[country_values.year==year]
    
    # convert to jason for bokeh
    country_values_json = json.loads(country_values.to_json())#Convert to String like object.
    json_data = json.dumps(country_values_json)

    # plot in bokeh
    #Input GeoJSON source that contains features for plotting.
    geosource = GeoJSONDataSource(geojson = json_data)
    #Define a sequential multi-hue color palette.
    palette = brewer['YlGnBu'][8]
    #Reverse color order so that dark blue is highest obesity.
    palette = palette[::-1]
    #Instantiate LinearColorMapper that linearly maps numbers in a range, into a sequence of colors.
    color_mapper = LinearColorMapper(palette = palette, low = 0.7, high = 2,  nan_color = '#d9d9d9')
    #Define custom tick labels for color bar.
    tick_labels = {'0': '0%', '5': '5%', '10':'10%', '15':'15%', '20':'20%', '25':'25%', '30':'30%','35':'35%', '40': '>40%'}
    #Create color bar. 
    color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 500, height = 20,
                         border_line_color=None,location = (0,0), orientation = 'horizontal', major_label_overrides = tick_labels)
    #Create figure object.
    p = figure(title = Title, plot_height = 900 , plot_width = 700, toolbar_location = None, 
               y_range=(30, 75), x_range=( -15, 35) )
    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    #Add patch renderer to figure. 
    p.patches('xs','ys', source = geosource,fill_color = {'field' :'value', 'transform' : color_mapper},
              line_color = 'black', line_width = 0.25, fill_alpha = 1)
    #Specify figure layout.
    p.add_layout(color_bar, 'below')
    #Display figure inline in Jupyter Notebook.
    output_notebook()
    #Display figure.
    show(p)

    return

# %%
plot_world_map(female_male_ratios)
# Out:
# in
#                 2012  2013  2014  2015  2016  2017  2018
# geo_time
# Austria            1     1     1     1     1     1     0
# Belgium            1     1     1     1     1     1     1
# Bulgaria           1     1     1     1     1     1     1
# Croatia            1     1     1     1     1     1     1
# Cyprus             1     1     1     1     1     1     1
# Czechia            1     1     1     1     1     1     1
# Denmark            1     1     1     1     1     1     1
# Estonia            1     1     1     1     1     1     1
# Finland            1     1     1     1     1     1     1
# France             1     1     1     1     1     1     1
# Germany            1     1     1     1     1     1     1
# Greece             1     1     1     1     1     1     1
# Hungary            1     1     1     1     1     1     1
# Ireland            1     1     1     1     1     1     1
# Italy              1     1     1     1     1     1     1
# Latvia             1     1     1     1     1     1     0
# Lithuania          1     1     1     1     1     1     1
# Luxembourg         1     1     1     1     1     1     1
# Macedonia          0     0     0     0     0     0     1
# Malta              1     1     1     1     1     1     1
# Montenegro         0     0     0     0     0     0     0
# Netherlands        1     1     1     1     1     1     1
# Norway             0     1     1     1     1     1     1
# Poland             1     1     1     1     1     1     1
# Portugal           1     1     1     1     1     1     1
# Romania            1     1     1     1     1     1     1
# Slovakia           1     1     1     1     1     1     1
# Slovenia           1     1     1     1     1     1     1
# Spain              1     1     1     1     1     1     1
# Sweden             0     0     1     1     1     1     1
# Switzerland        1     1     1     1     1     1     1
# United Kingdom     1     1     1     1     1     0     0
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3535">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c50480ad-1a51-4245-8f87-f8e8aa5d088e" data-root-id="3496"></div>

# %%
from bokeh.io import curdoc, output_notebook
from bokeh.models import Slider, HoverTool
from bokeh.layouts import widgetbox, row, column

def plot_world_interactive(data):
    # clean the data
    country_values = clean_to_plot(data, unpivot=True)
    
    #Define function that returns json_data for year selected by user.
    def json_data(selectedYear):
        year_country_values = country_values[country_values.year==selectedYear]
        merged_json = json.loads(year_country_values.to_json())
        json_data = json.dumps(merged_json)
        return json_data
    
    #Input GeoJSON source that contains features for plotting.
    geosource = GeoJSONDataSource(geojson = json_data('2016'))
    #Define a sequential multi-hue color palette.
    palette = brewer['YlGnBu'][8]
    #Reverse color order so that dark blue is highest obesity.
    palette = palette[::-1]
    #Instantiate LinearColorMapper that linearly maps numbers in a range, into a sequence of colors. Input nan_color.
    color_mapper = LinearColorMapper(palette = palette, low = 0.7, high = 2, nan_color = '#d9d9d9')
    #Define custom tick labels for color bar.
    tick_labels = {'0': '0%', '5': '5%', '10':'10%', '15':'15%', '20':'20%', '25':'25%', '30':'30%','35':'35%', '40': '>40%'}
    #Add hover tool
    hover = HoverTool(tooltips = [ ('Country/region','@country'),('value', '@value')])
    #Create color bar. 
    color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 500, height = 20,
                         border_line_color=None,location = (0,0), orientation = 'horizontal', major_label_overrides = tick_labels)
    #Create figure object.
    p = figure(title = 'Share of adults who are obese, 2016', plot_height = 900 , plot_width = 700, y_range=(30, 75), x_range=(-15, 35), toolbar_location = None, tools = [hover])
    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    #Add patch renderer to figure. 
    p.patches('xs','ys', source = geosource,fill_color = {'field' :'value', 'transform' : color_mapper},
              line_color = 'black', line_width = 0.25, fill_alpha = 1)
    #Specify layout
    p.add_layout(color_bar, 'below')
    
    
    # Define the callback function: update_plot
    def update_plot(attr, old, new):
        yr = slider.value
        new_data = json_data(str(yr))
        geosource.geojson = new_data
        p.title.text = 'Share of adults who are obese, %d' %yr

    # Make a slider object: slider 
    slider = Slider(title = 'Year',start = 2012, end = 2018, step = 1, value = 2016)
    slider.on_change('value', update_plot)
    # Make a column layout of widgetbox(slider) and plot, and add it to the current document
    layout = column(p,widgetbox(slider))
    curdoc().add_root(layout)
    
    #Display plot inline in Jupyter notebook
    output_notebook()
    #Display plot
    show(layout)

# %%
plot_world_interactive(female_male_ratios)
# Out:
# in
#                 2012  2013  2014  2015  2016  2017  2018
# geo_time
# Austria            1     1     1     1     1     1     0
# Belgium            1     1     1     1     1     1     1
# Bulgaria           1     1     1     1     1     1     1
# Croatia            1     1     1     1     1     1     1
# Cyprus             1     1     1     1     1     1     1
# Czechia            1     1     1     1     1     1     1
# Denmark            1     1     1     1     1     1     1
# Estonia            1     1     1     1     1     1     1
# Finland            1     1     1     1     1     1     1
# France             1     1     1     1     1     1     1
# Germany            1     1     1     1     1     1     1
# Greece             1     1     1     1     1     1     1
# Hungary            1     1     1     1     1     1     1
# Ireland            1     1     1     1     1     1     1
# Italy              1     1     1     1     1     1     1
# Latvia             1     1     1     1     1     1     0
# Lithuania          1     1     1     1     1     1     1
# Luxembourg         1     1     1     1     1     1     1
# Macedonia          0     0     0     0     0     0     1
# Malta              1     1     1     1     1     1     1
# Montenegro         0     0     0     0     0     0     0
# Netherlands        1     1     1     1     1     1     1
# Norway             0     1     1     1     1     1     1
# Poland             1     1     1     1     1     1     1
# Portugal           1     1     1     1     1     1     1
# Romania            1     1     1     1     1     1     1
# Slovakia           1     1     1     1     1     1     1
# Slovenia           1     1     1     1     1     1     1
# Spain              1     1     1     1     1     1     1
# Sweden             0     0     1     1     1     1     1
# Switzerland        1     1     1     1     1     1     1
# United Kingdom     1     1     1     1     1     0     0
#      country country_code                                           geometry  \
# 184  czechia          CZE  POLYGON ((18.83223 49.51079, 18.80703 49.50923...
#
#      year     value
# 184  2016  0.868485
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3940">Loading BokehJS ...</span>
#     </div>
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     http://bokeh.pydata.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     http://bokeh.pydata.org/en/latest/docs/user_guide/server.html
#   <div class="bk-root" id="64c23c02-a32e-4ba4-947e-574ced19c200" data-root-id="3780"></div>

# %%
# !bokeh serve --show Milestone_2.ipynb
# Out:
# 2019-12-10 23:54:33,732 Starting Bokeh server version 1.2.0 (running on Tornado 6.0.3)
# 2019-12-10 23:54:33,734 Bokeh app running at: http://localhost:5006/Milestone_2
# 2019-12-10 23:54:33,734 Starting Bokeh server with process id: 7914
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108 entries, 321 to 428
# Data columns (total 27 columns):
# sex         108 non-null object
# geo_time    108 non-null object
# 2018        96 non-null object
# 2017        87 non-null object
# 2016        90 non-null object
# 2015        90 non-null object
# 2014        90 non-null object
# 2013        87 non-null object
# 2012        84 non-null object
# 2011        0 non-null object
# 2010        0 non-null object
# 2009        0 non-null object
# 2008        0 non-null object
# 2007        0 non-null object
# 2006        0 non-null object
# 2005        0 non-null object
# 2004        0 non-null object
# 2003        0 non-null object
# 2002        0 non-null object
# 2001        0 non-null object
# 2000        0 non-null object
# 1999        0 non-null object
# 1998        0 non-null object
# 1997        0 non-null object
# 1996        0 non-null object
# 1995        0 non-null object
# 1994        0 non-null object
# dtypes: object(27)
# memory usage: 23.6+ KB
# in
#                 2012  2013  2014  2015  2016  2017  2018
# geo_time
# Austria            1     1     1     1     1     1     0
# Belgium            1     1     1     1     1     1     1
# Bulgaria           1     1     1     1     1     1     1
# Croatia            1     1     1     1     1     1     1
# Cyprus             1     1     1     1     1     1     1
# Czechia            1     1     1     1     1     1     1
# Denmark            1     1     1     1     1     1     1
# Estonia            1     1     1     1     1     1     1
# Finland            1     1     1     1     1     1     1
# France             1     1     1     1     1     1     1
# Germany            1     1     1     1     1     1     1
# Greece             1     1     1     1     1     1     1
# Hungary            1     1     1     1     1     1     1
# Ireland            1     1     1     1     1     1     1
# Italy              1     1     1     1     1     1     1
# Latvia             1     1     1     1     1     1     0
# Lithuania          1     1     1     1     1     1     1
# Luxembourg         1     1     1     1     1     1     1
# Macedonia          0     0     0     0     0     0     1
# Malta              1     1     1     1     1     1     1
# Montenegro         0     0     0     0     0     0     0
# Netherlands        1     1     1     1     1     1     1
# Norway             0     1     1     1     1     1     1
# Poland             1     1     1     1     1     1     1
# Portugal           1     1     1     1     1     1     1
# Romania            1     1     1     1     1     1     1
# Slovakia           1     1     1     1     1     1     1
# Slovenia           1     1     1     1     1     1     1
# Spain              1     1     1     1     1     1     1
# Sweden             0     0     1     1     1     1     1
# Switzerland        1     1     1     1     1     1     1
# United Kingdom     1     1     1     1     1     0     0
# 2019-12-10 23:54:35,077 /home/kiyarash/Desktop/ADA/project/ADA-Project/milestone2/Milestone_2.ipynb: call to output_notebook() ignored when running notebooks with the 'bokeh' command.
# 2019-12-10 23:54:35,077 /home/kiyarash/Desktop/ADA/project/ADA-Project/milestone2/Milestone_2.ipynb: call to show() ignored when running notebooks with the 'bokeh' command.
# in
#                 2012  2013  2014  2015  2016  2017  2018
# geo_time
# Austria            1     1     1     1     1     1     0
# Belgium            1     1     1     1     1     1     1
# Bulgaria           1     1     1     1     1     1     1
# Croatia            1     1     1     1     1     1     1
# Cyprus             1     1     1     1     1     1     1
# Czechia            1     1     1     1     1     1     1
# Denmark            1     1     1     1     1     1     1
# Estonia            1     1     1     1     1     1     1
# Finland            1     1     1     1     1     1     1
# France             1     1     1     1     1     1     1
# Germany            1     1     1     1     1     1     1
# Greece             1     1     1     1     1     1     1
# Hungary            1     1     1     1     1     1     1
# Ireland            1     1     1     1     1     1     1
# Italy              1     1     1     1     1     1     1
# Latvia             1     1     1     1     1     1     0
# Lithuania          1     1     1     1     1     1     1
# Luxembourg         1     1     1     1     1     1     1
# Macedonia          0     0     0     0     0     0     1
# Malta              1     1     1     1     1     1     1
# Montenegro         0     0     0     0     0     0     0
# Netherlands        1     1     1     1     1     1     1
# Norway             0     1     1     1     1     1     1
# Poland             1     1     1     1     1     1     1
# Portugal           1     1     1     1     1     1     1
# Romania            1     1     1     1     1     1     1
# Slovakia           1     1     1     1     1     1     1
# Slovenia           1     1     1     1     1     1     1
# Spain              1     1     1     1     1     1     1
# Sweden             0     0     1     1     1     1     1
# Switzerland        1     1     1     1     1     1     1
# United Kingdom     1     1     1     1     1     0     0
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
# 2019-12-10 23:54:35,263 /home/kiyarash/Desktop/ADA/project/ADA-Project/milestone2/Milestone_2.ipynb: call to output_notebook() ignored when running notebooks with the 'bokeh' command.
# 2019-12-10 23:54:35,263 /home/kiyarash/Desktop/ADA/project/ADA-Project/milestone2/Milestone_2.ipynb: call to show() ignored when running notebooks with the 'bokeh' command.
# 2019-12-10 23:54:35,264 Error running application handler <bokeh.application.handlers.notebook.NotebookHandler object at 0x7fb6654086d8>: name 'get_ipython' is not defined
# File "Milestone_2.ipynb", line 454, in <module>:
# "    <tr>\n", Traceback (most recent call last):
#   File "/home/kiyarash/anaconda3/lib/python3.7/site-packages/bokeh/application/handlers/code_runner.py", line 179, in run
#     exec(self._code, module.__dict__)
#   File "/home/kiyarash/Desktop/ADA/project/ADA-Project/milestone2/Milestone_2.ipynb", line 454, in <module>
#     "    <tr>\n",
# NameError: name 'get_ipython' is not defined
#
# 2019-12-10 23:54:35,274 200 GET /Milestone_2 (127.0.0.1) 1379.77ms
# 2019-12-10 23:54:35,419 101 GET /Milestone_2/ws?bokeh-protocol-version=1.0&bokeh-session-id=K0PE364VxCAAG3eUovH1PAKnajzJN7v4kCfajLbYiRhG (127.0.0.1) 0.57ms
# 2019-12-10 23:54:35,419 WebSocket connection opened
# 2019-12-10 23:54:35,419 ServerConnection created
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2013  0.983009
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2012  1.23077
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2013  0.983009
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2018  1.04279
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2013  0.983009
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2012  1.23077
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2013  0.983009
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2018  1.04279
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2013  0.983009
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2012  1.23077
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2013  0.983009
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2018  1.04279
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2013  0.983009
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2012  1.23077
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2013  0.983009
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2018  1.04279
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2018  1.04279
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2013  0.983009
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2014  1.01686
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2015  1.04972
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2016  0.868485
#
# [1 rows x 5 columns]
#      country country_code  ...  year     value
# 184  czechia          CZE  ...  2017  0.953505
#
# [1 rows x 5 columns]
#      country country_code  ...  year    value
# 184  czechia          CZE  ...  2018  1.04279
#
# [1 rows x 5 columns]
# 2019-12-10 23:55:51,335 WebSocket connection closed: code=1001, reason=None
# ^C
#
# Interrupted, shutting down

# %%
# read the geo data 
shapefile = 'data/ne_50m_admin_0_countries/ne_50m_admin_0_countries.shp'#Read shapefile using Geopandas
gdf = gpd.read_file(shapefile)[['ADMIN', 'ADM0_A3', 'geometry']]#Rename columns.
gdf.columns = ['country', 'country_code', 'geometry']

gdf[gdf.country.str.contains('Malta')]

# former yugoslav republic of macedonia, the / Macedonia
# czech republic , Czechia
# Out:
#     country country_code                                           geometry
# 112   Malta          MLT  MULTIPOLYGON (((14.56621 35.85273, 14.53271 35...

# %%
data = female_male_ratios

# get country out of index
data = data.reset_index()
# correct some country names
data.replace({'former yugoslav republic of macedonia, the': 'Macedonia', 'czech republic': 'Czechia'}, inplace=True)
data = data.set_index('geo_time')

# %%
# read the geo data 
shapefile = 'data/ne_50m_admin_0_countries/ne_50m_admin_0_countries.shp'#Read shapefile using Geopandas
gdf = gpd.read_file(shapefile)[['ADMIN', 'ADM0_A3', 'geometry']]#Rename columns.
gdf.columns = ['country', 'country_code', 'geometry']


##################################################
# correct some country names in data
#data[]

#lower case the country names for join
gdf['country'] = gdf.country.str.lower()
data.index = data.index.str.lower()
# join the geo data and values
country_values = gdf.join(data,on='country', how='right')
country_values
# Out:
#             country country_code  \
# 31   united kingdom          GBR
# 47      switzerland          CHE
# 48           sweden          SWE
# 54            spain          ESP
# 60         slovakia          SVK
# 61         slovenia          SVN
# 76          romania          ROU
# 78         portugal          PRT
# 79           poland          POL
# 88           norway          NOR
# 96      netherlands          NLD
# 105      montenegro          MNE
# 112           malta          MLT
# 118       macedonia          MKD
# 119      luxembourg          LUX
# 120       lithuania          LTU
# 126          latvia          LVA
# 137           italy          ITA
# 140         ireland          IRL
# 146         hungary          HUN
# 154          greece          GRC
# 156         germany          DEU
# 160          france          FRA
# 224  POLYGON ((9.52754 47.27075, 9.60908 47.39180, ...  0.916072  1.009566
#
#          2014      2015      2016      2017      2018
# 31   0.999793  0.900369  0.999779       NaN       NaN
# 47   1.088981  1.018212  1.066623  1.162344  1.158204
# 48   0.924908  1.002496  0.876442  0.814452  1.594111
# 54   1.057124  1.151926  1.031184  0.970718  1.148497
# 60   1.432111  0.883349  1.033426  1.026807  0.951390
# 61   0.945442  0.961722  0.911500  1.072310  1.006263
# 76   1.031544  1.125551  1.094222  1.027342  0.992080
# 78   0.930133  1.077497  1.027539  1.133892  1.362083
# 79   0.962305  0.972501  0.989355  0.961276  1.001859
# 88   0.866875  0.837804  0.896233  1.025805  0.766410
# 96   0.928140  0.935952  0.826988  0.937062  0.968058
# 105       NaN       NaN       NaN       NaN       NaN
# 112  1.303072  0.988227  1.068726  0.950671  0.903736
# 118       NaN       NaN       NaN       NaN  1.067793
# 119  0.980815  1.017641  0.968336  0.998389  0.991010
# 120  1.068853  1.105070  1.199028  1.265486  1.270010
# 126  1.580497  1.356402  1.463916  1.409976       NaN
# 137  1.108865  0.914494  1.078158  1.042866  0.925583
# 140  1.425145  0.927069  0.941029  0.953131  0.930140
# 146  1.037448  1.061559  1.015116  1.049411  0.950590
# 154  1.028124  0.975511  1.145966  1.238806  1.074845
# 156  1.034135  1.139888  1.063839  1.048792  0.899497
# 160  1.070551  1.019411  0.892028  1.136035  0.938672
# 169  0.974166  1.302306  1.195244  1.819267  0.963977
# 172  1.192968  1.103785  1.746726  1.221506  1.065868
# 183  1.086463  1.050776  0.911323  1.030794  0.960793
# 184  1.016861  1.049720  0.868485  0.953505  1.042789
# 186  1.234714  1.206169  1.154014  1.079284  1.080140
# 188  1.270082  1.102596  1.047424  0.824110  0.952054
# 208  1.216715  1.362314  1.059165  1.015261  1.249361
# 217  1.070231  1.113437  1.179897  1.000208  1.032098
# 224  1.153725  0.990926  1.115429  0.998849       NaN

# %% [markdown]
# ## How sex, education, etc. affect the money spent by tourists? Are there specific target countries for each group of people?

# %%
#read
money_sex = pd.read_csv('data/tour_dem_exsex.tsv', sep='\t')

# use clean function in the pervious section
money_sex = clean(money_sex)

# %%
money_sex
# Out:
#      unit,purpose,duration,partner,sex,geo\time         2018         2017  \
# 0                    THS_EUR,PERS,N1-3,DOM,F,AT       993188       914896
# 1                    THS_EUR,PERS,N1-3,DOM,F,BE       180605       178816
# 2                    THS_EUR,PERS,N1-3,DOM,F,BG      70751.4      79555.7
# 3                    THS_EUR,PERS,N1-3,DOM,F,CH       353121       437326
# 4                    THS_EUR,PERS,N1-3,DOM,F,CY      70798.8      61388.3
# 5                    THS_EUR,PERS,N1-3,DOM,F,CZ       422126       415186
# 6                    THS_EUR,PERS,N1-3,DOM,F,DE  8.01606e+06  6.52657e+06
# 7                    THS_EUR,PERS,N1-3,DOM,F,DK  1.04136e+06  1.79962e+06
# 8                    THS_EUR,PERS,N1-3,DOM,F,EE       204784       102234
# 9                    THS_EUR,PERS,N1-3,DOM,F,EL       129135       107818
# 10                   THS_EUR,PERS,N1-3,DOM,F,ES  5.41385e+06  5.08337e+06
# 11                   THS_EUR,PERS,N1-3,DOM,F,FI  1.35306e+06     1.41e+06
# 12                   THS_EUR,PERS,N1-3,DOM,F,FR  6.17448e+06  7.36079e+06
# 13                   THS_EUR,PERS,N1-3,DOM,F,HR      61656.9      61102.3
# 14                   THS_EUR,PERS,N1-3,DOM,F,HU       289384       283843
# 15                   THS_EUR,PERS,N1-3,DOM,F,IE       620101       551976
# 16                   THS_EUR,PERS,N1-3,DOM,F,IT  2.17703e+06  1.87902e+06
# 17                   THS_EUR,PERS,N1-3,DOM,F,LT      61154.6      57571.6
# 18                   THS_EUR,PERS,N1-3,DOM,F,LU      1814.73      1031.27
# 19                   THS_EUR,PERS,N1-3,DOM,F,LV      53576.4      46923.9
# 20                   THS_EUR,PERS,N1-3,DOM,F,MT      14291.6      14783.5
# 21                   THS_EUR,PERS,N1-3,DOM,F,NL       903345       749230
# 22                   THS_EUR,PERS,N1-3,DOM,F,NO  1.37744e+06  1.02764e+06
# 23                   THS_EUR,PERS,N1-3,DOM,F,PL          NaN       988889
# 24                   THS_EUR,PERS,N1-3,DOM,F,PT       419154       364119
# 25                   THS_EUR,PERS,N1-3,DOM,F,RO          NaN       398687
# 26                   THS_EUR,PERS,N1-3,DOM,F,SE          NaN          NaN
# 27                   THS_EUR,PERS,N1-3,DOM,F,SI      53962.1      54398.2
# 28                   THS_EUR,PERS,N1-3,DOM,F,SK       279152       217172
# 29                   THS_EUR,PERS,N1-3,DOM,F,UK          NaN          NaN
# ...                                         ...          ...          ...
# 4834             THS_NAC,TOTAL,N_GE4,WORLD,T,AT  1.10556e+07  1.05094e+07
# 4835             THS_NAC,TOTAL,N_GE4,WORLD,T,BE  7.99474e+06  6.91088e+06
# 4836             THS_NAC,TOTAL,N_GE4,WORLD,T,BG  1.23715e+06  1.17085e+06
# 4837             THS_NAC,TOTAL,N_GE4,WORLD,T,CH  1.54201e+07  1.49932e+07
# 4838             THS_NAC,TOTAL,N_GE4,WORLD,T,CY  1.28787e+06  1.31265e+06
# 4839             THS_NAC,TOTAL,N_GE4,WORLD,T,CZ  1.03975e+08  1.00209e+08
# 4840             THS_NAC,TOTAL,N_GE4,WORLD,T,DE  1.29444e+08  9.83785e+07
# 4841             THS_NAC,TOTAL,N_GE4,WORLD,T,DK  8.19549e+07   7.8834e+07
# 4842             THS_NAC,TOTAL,N_GE4,WORLD,T,EE  1.22961e+06       678629
# 4843             THS_NAC,TOTAL,N_GE4,WORLD,T,EL  1.95043e+06  1.61842e+06
# 4844             THS_NAC,TOTAL,N_GE4,WORLD,T,ES  2.59266e+07  2.42433e+07
# 4845             THS_NAC,TOTAL,N_GE4,WORLD,T,FI  8.21923e+06  7.35343e+06
# 4846             THS_NAC,TOTAL,N_GE4,WORLD,T,FR  9.04266e+07  6.02401e+07
NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1             NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2             NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3             NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4             NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5             NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6             NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7             NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8             NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9          160118  NaN  NaN  NaN  NaN  NaN  NaN
# 10            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 11            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 12            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 14            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 15            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 16            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 17            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 18            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 19            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 21            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 22            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 23            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 24            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 25            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 26            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 27            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 28            NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 29    1.57041e+06  NaN  NaN  NaN  NaN  NaN  NaN
# ...           ...  ...  ...  ...  ...  ...  ...
# 4834          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4835          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4836          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4837          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4838          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4839          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4840          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4841          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4842          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4843          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4844          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4845          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4846          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4847          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4848          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4849          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4850          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4851          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4852          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4853          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4854          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4855          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4856          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4857          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4858          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4859          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4860          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4861          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4862          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4863          NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [4864 rows x 30 columns]

# %%
# turn the first column into different columns 'specs'
specs = money_sex.iloc[:,0].str.split(',', expand=True)
specs.columns = ['unit', 'purpose', 'duration', 'partner', 'sex', 'geo_time']
# now join with the numeric data
money_sex = pd.concat([specs, money_sex.iloc[:,1:]], axis=1)

# %%
money_sex.sample()
# Out:
#          unit purpose duration partner sex geo_time 2018 2017 2016 2015  ...  \
# 3033  THS_NAC    PERS    N_GE4     DOM   M       UK  NaN  NaN  NaN  NaN  ...
#
#            1999        1998       1997       1996 1995 1994 1993 1992 1991  \
# 3033  3.547e+06  3.0551e+06  3.198e+06  3.116e+06  NaN  NaN  NaN  NaN  NaN
#
#      1990
# 3033  NaN
#
# [1 rows x 35 columns]

# %%
# turn country codes into names
# turn code into name
money_sex['geo_time'] = money_sex['geo_time'].map(di).fillna(money_sex['geo_time'])

# %% [markdown]
# for now we will concentrate on the most general data possible (except purpose):
#
# * unit: THS_EUR (thousands of euros)
# * duration: N_GE1 (1 nights or more)
# * partner: OUT (outbound trips; trips of non-citizens to this country)
# * purpose: PERS (personal)
# * sex and geo all of the options

# %%
selection = (money_sex.unit=='THS_EUR') & (money_sex.duration=='N_GE1') & (money_sex.partner=='OUT') & (money_sex.purpose=='PERS')
money_sex = money_sex[selection]

# drop spec columns
money_sex.drop(labels=['unit', 'duration', 'partner', 'purpose'], axis =1, inplace=True)

# %%
money_sex.sample()
# Out:
#     sex geo_time    2018    2017    2016    2015    2014    2013    2012  \
# 381   F    Malta  213863  186060  187937  131091  133621  131442  116178
#
#       2011  ... 1999 1998 1997 1996 1995 1994 1993 1992 1991 1990
# 381  96431  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [1 rows x 31 columns]

# %% [markdown]
# below we can see that years 2002 and before only half the countries or less have available data.
# we can drop them. but we will keep them until handelling them would be necessary.

# %%
money_sex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 361 to 451
# Data columns (total 31 columns):
# sex         91 non-null object
# geo_time    91 non-null object
# 2018        78 non-null object
# 2017        84 non-null object
# 2016        87 non-null object
# 2015        87 non-null object
# 2014        87 non-null object
# 2013        87 non-null object
# 2012        81 non-null object
# 2011        68 non-null object
# 2010        70 non-null object
# 2009        65 non-null object
# 2008        60 non-null object
# 2007        65 non-null object
# 2006        54 non-null object
# 2005        50 non-null object
# 2004        51 non-null object
# 2003        44 non-null object
# 2002        29 non-null object
# 2001        28 non-null object
# 2000        26 non-null object
# 1999        23 non-null object
# 1998        23 non-null object
# 1997        19 non-null object
# 1996        9 non-null object
# 1995        15 non-null object
# 1994        16 non-null object
# 1993        15 non-null object
# 1992        15 non-null object
# 1991        15 non-null object
# 1990        15 non-null object
# dtypes: object(31)
# memory usage: 22.8+ KB

# %% [markdown]
# ## EDA

# %% [markdown]
# male vs female spending:

# %%
money_female =  money_sex[money_sex.sex=='F']
# sort columns
money_female = money_female.reindex(sorted(money_female.columns), axis=1)

female_total = money_female.sum()[:29].sum()

# %%
money_male =  money_sex[money_sex.sex=='M']
# sort columns
money_male = money_male.reindex(sorted(money_male.columns), axis=1)

male_total = money_male.sum()[:29].sum()

# %%
plt.bar(['male','female'],[male_total, female_total])
# Out:
# <BarContainer object of 2 artists>

# %%
[male_total, female_total]
# Out:
# [1652071621.3899999, 1631929211.3899999]

# %%
money_male.sum()[:29].std()
# Out:
# 38929561.881667495

# %%
money_female.sum()[:29].std()
# Out:
# 39290134.79041095

# %% [markdown]
# so there is no significant difference between the two genders in spending.

# %%
money_male.sum()[:29].plot.bar()
plt.title('male spending');

# %%
money_female.sum()[:29].plot.bar()
plt.title('female spending');

# %%
colors = plt.cm.nipy_spectral(np.linspace(0, 1, 30))  #Pastel1 gist_rainbow
money_male.set_index('geo_time').drop('sex', axis=1).T.plot.bar(stacked=True, figsize=(20,15), color=colors)
plt.title('Money spent by males thousands of euros')
# Out:
# Text(0.5, 1.0, 'Money spent by males thousands of euros')

# %%
colors = plt.cm.nipy_spectral(np.linspace(0, 1, 30))  #Pastel1 gist_rainbow
money_female.set_index('geo_time').drop('sex', axis=1).T.plot.bar(stacked=True, figsize=(20,15), color=colors)
plt.title('Money spent by females thousands of euros')
# Out:
# Text(0.5, 1.0, 'Money spent by females thousands of euros')

# %% [markdown]
# top ten countries females spent money in:

# %%
money_female = money_female.set_index('geo_time').drop('sex', axis=1)

# %%
money_female.sum(axis=1).sort_values(ascending=False).head(10)
# Out:
# geo_time
# Germany           5.918584e+08
# United Kingdom    2.894117e+08
# France            1.519891e+08
# Netherlands       1.062712e+08
# Italy             7.044132e+07
# Spain             6.526663e+07
# Switzerland       5.813414e+07
# Ireland           3.674515e+07
# Sweden            3.017214e+07
# Austria           2.969247e+07
# dtype: float64

# %%
money_male = money_male.set_index('geo_time').drop('sex', axis=1)

# %%
money_male.sum(axis=1).sort_values(ascending=False).head(10)
# Out:
# geo_time
# Germany           6.305603e+08
# United Kingdom    3.081493e+08
# France            1.371139e+08
# Netherlands       1.092657e+08
# Italy             6.757808e+07
# Spain             5.709939e+07
# Switzerland       5.639498e+07
# Sweden            3.349369e+07
# Norway            3.261406e+07
# Ireland           3.182447e+07
# dtype: float64

# %% [markdown]
# we see that Norway is only in the male top 10 spending while Austria is only in female top 10 spendings.

# %% [markdown]
# ### Next steps:
# 1. we can use the participation data and the spending to train a classifier for countries. this way we can use the weights to determin the target country of each group of people.
#
# 2. we again can use ARIMA to do timeseries prediction.
#
# 3. if we can get access to micro data we can do a predition task on types of people to predict their spending.
